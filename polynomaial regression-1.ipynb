# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('/Users/palammysurareddy/Downloads/emp_sal - emp_sal.csv')
dataset
# Out:
#                Position  Level   Salary
# 0  Jr Software Engineer      1    45000
# 1  Sr Software Engineer      2    50000
# 2             Team Lead      3    60000
# 3               Manager      4    80000
# 4            Sr manager      5   110000
# 5        Region Manager      6   150000
# 6                   AVP      7   200000
# 7                    VP      8   300000
# 8                   CTO      9   500000
# 9                   CEO     10  1000000

# %%
x=dataset.iloc[:,1:2].values
y=dataset.iloc[:,1].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color='red')
plt.plot(x,lin_reg.predict(x),color='blue')
plt.title('linear regresion model(linear regression)')
plt.xlabel('position level')
plt.ylabel('salary')
plt.show()

# %%
lin_reg_pred=lin_reg.predict(([[7]]))
lin_reg_pred
# Out:
# array([7.])

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures()
x_poly=poly_reg.fit_transform(x)

# %%
poly_reg.fit(x_poly,y)
# Out:
# PolynomialFeatures()

# %%
lin_reg_2=LinearRegression()
lin_reg_2.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color='red')
plt.plot(x,lin_reg_2.predict(poly_reg.fit_transform(x)),color='blue')
plt.title('poly nomial(polynomial Regression)')
plt.xlabel('postion level')
plt.ylabel('salary')
plt.show()

# %%
poly_reg_pred=lin_reg_2.predict(poly_reg.fit_transform(([[7]])))
poly_reg_pred
# Out:
# array([7.])
