# %%
#pip install smolagents

# %%
import os 
os.environ["HF_TOKEN"]="enter your api key"

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel
#
# ImportError: cannot import name 'HfApiModel' from 'smolagents' (/opt/anaconda3/lib/python3.12/site-packages/smolagents/__init__.py)

# %%
model =InferenceClientModel ()
agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model)

# %%
agent.run('differential human brian & machine brian')
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ differential human brian & machine brian                                                                        │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# 401 Client Error: Unauthorized for url:
# https://huggingface.co/api/models/Qwen/Qwen2.5-Coder-32B-Instruct?expand=inferenceProviderMapping (Request ID:
# Root=1-68e88f3b-45a5dbc44887a74257d46b72;e0327fe4-ca64-4b02-81ef-3502c3115a86)
#
# ...

# %%
from smolagents import ToolCallingAgent

# %%
tool_agent = ToolCallingAgent(tools=[DuckDuckGoSearchTool()], model = model)

# %%
tool_agent.run('agentic job market in 2025')

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel
import os

# Initialize the Hugging Face API Model
# It'll look for an HF_TOKEN in your environment variables for authentication
model = HfApiModel(
    model_id="Qwen/Qwen2.5-Coder-32B-Instruct", # or any other model on the Hub
    token=os.environ.get("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") # Safely load your token
)

# Initialize a CodeAgent with the model and a tool
agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model
)

# Run the agent's task
result = agent.run("Who was the last US President born in the 1940s?")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel
#       2 import os
#       4 # Initialize the Hugging Face API Model
#       5 # It'll look for an HF_TOKEN in your environment variables for authentication
#
# ImportError: cannot import name 'HfApiModel' from 'smolagents' (/opt/anaconda3/lib/python3.12/site-packages/smolagents/__init__.py)

# %%
from smolagents.models import HfApiModel # Corrected import
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from smolagents.models import HfApiModel
#
# ImportError: cannot import name 'HfApiModel' from 'smolagents.models' (/opt/anaconda3/lib/python3.12/site-packages/smolagents/models.py)

# %%
from smolagents import InferenceClientModel

# Then use it in your code
model = InferenceClientModel(...)
