# %%
import requests
import json

response = requests.post(
  url="https://openrouter.ai/api/v1/chat/completions",
  headers={
    "Authorization": "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",
    "Content-Type": "application/json",
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  data=json.dumps({
    "model": "openai/gpt-5-pro",
    "messages": [
      {
        "role": "user",
        "content": [
          {
            "type": "text",
            "text": "What is in this image?"
          },
          {
            "type": "image_url",
            "image_url": {
              "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"
            }
          }
        ]
      }
    ],

  })
)

# %%
print(response)
# Out:
# <Response [401]>

# %%
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="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",
)

completion = client.chat.completions.create(
  extra_headers={
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  extra_body={},
  model="openai/gpt-5-pro",
  messages=[
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "What is in this image?"
        },
        {
          "type": "image_url",
          "image_url": {
            "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"
          }
        }
      ]
    }
  ]
)
print(completion.choices[0].message.content)
# Out:
# A wooden boardwalk path runs through a lush green field or wetland, bordered by tall grass and shrubs, under a blue sky with scattered clouds. Trees line the distant horizon.

# %%
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="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",
)

completion = client.chat.completions.create(
  extra_headers={
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  extra_body={},
  model="google/gemini-2.5-flash-image",
  messages=[
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "What is in this image?"
        },
        {
          "type": "image_url",
          "image_url": {
            "url": ""
          }
        }
      ]
    }
  ]
)
print(completion.choices[0].message.content)
# Out:
# This image shows a wooden boardwalk extending into a lush green field under a vast blue sky with scattered clouds. The boardwalk runs straight down the center of the frame, leading the eye into the distance. On either side, tall green grass dominates the foreground and midground, while trees and bushes form a natural horizon line further back. The lighting suggests either early morning or late afternoon, with a gentle glow on the vegetation.

# %%
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="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",
)

completion = client.chat.completions.create(
  extra_headers={
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  extra_body={},
  model="deepseek/deepseek-v3.2-exp",
  messages=[
    {
      "role": "user",
      "content": "What is the meaning of life?"
    }
  ]
)
print(completion.choices[0].message.content)
# Out:
# That is one of the most profound and enduring questions humanity has ever asked. There isn't one single, universally accepted answer, because the meaning of life is deeply personal and can be viewed through many different lenses.
#
# Here is a breakdown of the most common perspectives on the meaning of life, from the philosophical to the scientific.
#
# ### 1. Philosophical & Existential Perspectives
#
# This school of thought argues that life has no *inherent* meaning, and that is its great gift. We are not born with a pre-written purpose; instead, we are free to create our own.
#
# ...
