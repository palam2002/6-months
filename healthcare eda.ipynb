# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 6.5 MB/s eta 0:00:0000:0100:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 5.1 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib]6 [matplotlib]
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install seaborn

# %%
healthcare_d=pd.read_csv("/Users/palammysurareddy/Downloads/healthcare_dataset.csv").head(23)
healthcare_d
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 0         Bobby JacksOn   30    Male         B-            Cancer
# 1          LesLie TErRy   62    Male         A+           Obesity
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 3          andrEw waTtS   28  Female         O+          Diabetes
# 4         adrIENNE bEll   43  Female        AB+            Cancer
# 5         EMILY JOHNSOn   36    Male         A+            Asthma
# 6        edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7    CHrisTInA MARtinez   20  Female         A+            Cancer
# 8       JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9      ChRISTopher BerG   58  Female        AB-            Cancer
# 10     mIchElLe daniELs   72    Male         O+            Cancer
# 11       aaRon MARtiNeZ   38  Female         A-      Hypertension
# 12        connOR HANsEn   75  Female         A+          Diabetes
# ...

# %%
healthcare_data.shape
# Out:
# (23, 15)

# %%
healthcare_data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
healthcare_data.shape
# Out:
# (23, 15)

# %%
healthcare_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                23 non-null     object
#  1   Age                 23 non-null     int64
#  2   Gender              23 non-null     object
#  3   Blood Type          23 non-null     object
#  4   Medical Condition   23 non-null     object
#  5   Date of Admission   23 non-null     object
#  6   Doctor              23 non-null     object
#  7   Hospital            23 non-null     object
#  8   Insurance Provider  23 non-null     object
#  9   Billing Amount      23 non-null     float64
#  10  Room Number         23 non-null     int64
#  11  Admission Type      23 non-null     object
#  12  Discharge Date      23 non-null     object
#  13  Medication          23 non-null     object
#  14  Test Results        23 non-null     object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
healthcare_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                23 non-null     object
#  1   Age                 23 non-null     int64
#  2   Gender              23 non-null     object
#  3   Blood Type          23 non-null     object
#  4   Medical Condition   23 non-null     object
#  5   Date of Admission   23 non-null     object
#  6   Doctor              23 non-null     object
#  7   Hospital            23 non-null     object
#  8   Insurance Provider  23 non-null     object
#  9   Billing Amount      23 non-null     float64
#  10  Room Number         23 non-null     int64
#  11  Admission Type      23 non-null     object
#  12  Discharge Date      23 non-null     object
#  13  Medication          23 non-null     object
#  14  Test Results        23 non-null     object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
healthcare_d
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 0         Bobby JacksOn   30    Male         B-            Cancer
# 1          LesLie TErRy   62    Male         A+           Obesity
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 3          andrEw waTtS   28  Female         O+          Diabetes
# 4         adrIENNE bEll   43  Female        AB+            Cancer
# 5         EMILY JOHNSOn   36    Male         A+            Asthma
# 6        edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7    CHrisTInA MARtinez   20  Female         A+            Cancer
# 8       JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9      ChRISTopher BerG   58  Female        AB-            Cancer
# 10     mIchElLe daniELs   72    Male         O+            Cancer
# 11       aaRon MARtiNeZ   38  Female         A-      Hypertension
# 12        connOR HANsEn   75  Female         A+          Diabetes
# ...

# %%
healthcare_d.isnull()
# Out:
#      Name    Age  Gender  Blood Type  Medical Condition  Date of Admission  \
# 0   False  False   False       False              False              False
# 1   False  False   False       False              False              False
# 2   False  False   False       False              False              False
# 3   False  False   False       False              False              False
# 4   False  False   False       False              False              False
# 5   False  False   False       False              False              False
# 6   False  False   False       False              False              False
# 7   False  False   False       False              False              False
# 8   False  False   False       False              False              False
# 9   False  False   False       False              False              False
# 10  False  False   False       False              False              False
# ...

# %%
healthcare_d.sum()
# Out:
# Name                  Bobby JacksOnLesLie TErRyDaNnY sMitHandrEw waT...
# Age                                                                1170
# Gender                MaleMaleFemaleFemaleFemaleMaleFemaleFemaleMale...
# Blood Type            B-A+A-O+AB+A+AB-A+AB+AB-O+A-A+AB+AB+AB-A+AB-A-...
# Medical Condition     CancerObesityObesityDiabetesCancerAsthmaDiabet...
# Date of Admission     2024-01-312019-08-202022-09-222020-11-182022-0...
# Doctor                Matthew SmithSamantha DaviesTiffany MitchellKe...
# Hospital              Sons and MillerKim IncCook PLCHernandez Rogers...
# Insurance Provider    Blue CrossMedicareAetnaMedicareAetnaUnitedHeal...
# Billing Amount                                            574366.502963
# Room Number                                                        7123
# Admission Type        UrgentEmergencyEmergencyElectiveUrgentUrgentEm...
# Discharge Date        2024-02-022019-08-262022-10-072020-12-182022-1...
# ...

# %%
healthcare_d['Name']
# Out:
# 0           Bobby JacksOn
# 1            LesLie TErRy
# 2             DaNnY sMitH
# 3            andrEw waTtS
# 4           adrIENNE bEll
# 5           EMILY JOHNSOn
# 6          edwArD EDWaRDs
# 7      CHrisTInA MARtinez
# 8         JASmINe aGuIlaR
# 9        ChRISTopher BerG
# 10       mIchElLe daniELs
# 11         aaRon MARtiNeZ
# 12          connOR HANsEn
# 13           rObeRt bAuer
# 14           bROOkE brady
# 15     MS. nAtalIE gAMble
# 16          haley perkins
# 17    mRS. jamiE cAMPBELl
# 18           LuKE BuRgEss
# 19         dANIEL schmIdt
# 20          tIMOTHY burNs
# 21     ChRISToPHEr BRiGhT
# 22        KatHRYn StewArt
# Name: Name, dtype: object

# %%
healthcare_d['Name']=healthcare_d['Name'].str.replace(r'\w','')
healthcare_d['Name']
# Out:
# 0           Bobby JacksOn
# 1            LesLie TErRy
# 2             DaNnY sMitH
# 3            andrEw waTtS
# 4           adrIENNE bEll
# 5           EMILY JOHNSOn
# 6          edwArD EDWaRDs
# 7      CHrisTInA MARtinez
# 8         JASmINe aGuIlaR
# 9        ChRISTopher BerG
# 10       mIchElLe daniELs
# 11         aaRon MARtiNeZ
# 12          connOR HANsEn
# 13           rObeRt bAuer
# 14           bROOkE brady
# 15     MS. nAtalIE gAMble
# 16          haley perkins
# 17    mRS. jamiE cAMPBELl
# 18           LuKE BuRgEss
# 19         dANIEL schmIdt
# 20          tIMOTHY burNs
# 21     ChRISToPHEr BRiGhT
# 22        KatHRYn StewArt
# Name: Name, dtype: object

# %%
healthcare_d['Age']
# Out:
# 0     30
# 1     62
# 2     76
# 3     28
# 4     43
# 5     36
# 6     21
# 7     20
# 8     82
# 9     58
# 10    72
# 11    38
# 12    75
# 13    68
# 14    44
# 15    46
# 16    63
# 17    38
# 18    34
# 19    63
# 20    67
# 21    48
# 22    58
# Name: Age, dtype: int64

# %%
healthcare_d['Gender']
# Out:
# 0       Male
# 1       Male
# 2     Female
# 3     Female
# 4     Female
# 5       Male
# 6     Female
# 7     Female
# 8       Male
# 9     Female
# 10      Male
# 11    Female
# 12    Female
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20    Female
# 21      Male
# 22    Female
# Name: Gender, dtype: object

# %%
fig,ax=plt.subplots(figsize=(8,6))
x=healthcare_d['Age']
ax=sns.distplot(x,bins=10,vertical=True)

# %%
f, ax = plt.subplots(figsize=(8,6))
x = healthcare_d['Age']
x = pd.Series(x, name="Age variable")
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = healthcare_d['Age']
x = pd.Series(x, name="Age variable")
ax = sns.kdeplot(x,color='g',shade=True)
plt.show()

# %%
healthcare_d['Doctor']
# Out:
# 0        Matthew Smith
# 1      Samantha Davies
# 2     Tiffany Mitchell
# 3          Kevin Wells
# 4       Kathleen Hanna
# 5        Taylor Newton
# 6          Kelly Olson
# 7       Suzanne Thomas
# 8      Daniel Ferguson
# 9          Heather Day
# 10         John Duncan
# 11        Douglas Mayo
# 12    Kenneth Fletcher
# 13     Theresa Freeman
# 14     Roberta Stewart
# 15     Maria Dougherty
# 16       Erica Spencer
# 17          Justin Kim
# 18    Justin Moore Jr.
# 19     Denise Galloway
# 20        Krista Smith
# 21       Gregory Smith
# 22      Vanessa Newton
# Name: Doctor, dtype: object

# %%
healthcare_d['Doctor'] = healthcare_d['Doctor'].str.replace(r'\w','')

# %%
healthcare_d['Doctor']
# Out:
# 0        Matthew Smith
# 1      Samantha Davies
# 2     Tiffany Mitchell
# 3          Kevin Wells
# 4       Kathleen Hanna
# 5        Taylor Newton
# 6          Kelly Olson
# 7       Suzanne Thomas
# 8      Daniel Ferguson
# 9          Heather Day
# 10         John Duncan
# 11        Douglas Mayo
# 12    Kenneth Fletcher
# 13     Theresa Freeman
# 14     Roberta Stewart
# 15     Maria Dougherty
# 16       Erica Spencer
# 17          Justin Kim
# 18    Justin Moore Jr.
# 19     Denise Galloway
# 20        Krista Smith
# 21       Gregory Smith
# 22      Vanessa Newton
# Name: Doctor, dtype: object

# %%
healthcare_d['Gender'] = healthcare_d['Gender'].str.replace(r'\w','')
healthcare_d["Gender"]
# Out:
# 0       Male
# 1       Male
# 2     Female
# 3     Female
# 4     Female
# 5       Male
# 6     Female
# 7     Female
# 8       Male
# 9     Female
# 10      Male
# 11    Female
# 12    Female
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20    Female
# 21      Male
# 22    Female
# Name: Gender, dtype: object

# %%
healthcare_d=clean_data.info()
healthcare_d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 healthcare_d=clean_data.info()
#       2 healthcare_d
#
# NameError: name 'clean_data' is not defined
