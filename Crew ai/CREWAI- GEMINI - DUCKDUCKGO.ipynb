# %%
'''
create a requirment.txt
    crewai
    duckduckgo-search
    huggingface_hub
    langchain_google_genai
'''
# Out:
# '\ncreate a requirment.txt\n    crewai\n    duckduckgo-search\n    huggingface_hub\n    langchain_google_genai\n'

# %%
pip install -r requirement.txt
# Out:
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirement.txt'
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from crewai import Agent, Task, Crew, Process
from langchain.tools import DuckDuckGoSearchRun
from crewai import Agent, Task, Crew, Process

# %%
# Set gemini pro as llm
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",
                             verbose = True,
                             temperature = 0.5,
                             google_api_key="AIzaSyC1xzdPqtDpP96JK18LeQOT5naE3Ies7bk")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760253428.638644  316678 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.

# %%
#google new model == gemini-1.5-flash-8b-exp-0827

# %%
#create searches
tool_search = DuckDuckGoSearchRun()

# %%
from crewai import Agent

# Dummy agent
test_agent = Agent(
    role="Tester",
    goal="Just testing",
    backstory="Testing Agent class",
    verbose=True,
    allow_delegation=False
)

print(test_agent)
# Out:
# id=UUID('2e0c8f23-487e-4849-967e-3805afdf6eb0') role='Tester' goal='Just testing' backstory='Testing Agent class' config=None cache=True verbose=True max_rpm=None allow_delegation=False tools=[] max_iter=25 agent_executor=<crewai.agents.crew_agent_executor.CrewAgentExecutor object at 0x301e509b0> llm=<crewai.llm.LLM object at 0x301e51c70> crew=None i18n=I18N(prompt_file=None) cache_handler=CacheHandler() tools_handler=<crewai.agents.tools_handler.ToolsHandler object at 0x301e50f80> tools_results=[] max_tokens=None knowledge=None knowledge_sources=None knowledge_storage=None security_config=SecurityConfig(fingerprint=Fingerprint(metadata={})) callbacks=[] adapted_agent=False knowledge_config=None max_execution_time=None agent_ops_agent_name='Tester' agent_ops_agent_id=None step_callback=None use_system_prompt=True function_calling_llm=None system_template=None prompt_template=None response_template=None allow_code_execution=False respect_context_window=True max_retry_limit=2 multimodal=False inject_date=False date_format='%Y-%m-%d' code_execution_mode='safe' reasoning=False max_reasoning_attempts=None embedder=None agent_knowledge_context=None crew_knowledge_context=None knowledge_search_query=None from_repository=None guardrail=None guardrail_max_retries=3
