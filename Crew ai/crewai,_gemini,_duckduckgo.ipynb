# %%
'''
create a requirment.txt
    crewai
    duckduckgo-search
    huggingface_hub
    langchain_google_genai
'''
# Out:
# '\ncreate a requirment.txt\n    crewai\n    duckduckgo-search\n    huggingface_hub\n    langchain_google_genai\n'

# %%
# !pip install -r requirment.txt
# Out:
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirment.txt'

# %%
pip install crewai
# Out:
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# Collecting crewai
#   Using cached crewai-0.203.0-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (1.4.4)
# Collecting blinker>=1.9.0 (from crewai)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: chromadb~=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: click>=8.1.7 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (8.3.0)
# Collecting instructor>=1.3.3 (from crewai)
#   Using cached instructor-1.11.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: json-repair==0.25.2 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (0.25.2)
# Requirement already satisfied: json5>=0.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (0.12.1)
# Requirement already satisfied: jsonref>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (1.1.0)
# Collecting litellm==1.74.9 (from crewai)
#   Using cached litellm-1.74.9-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: openai>=1.13.3 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (1.108.2)
# Requirement already satisfied: openpyxl>=3.1.5 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.30.0 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (1.37.0)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.30.0 (from crewai)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.37.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (1.37.0)
# Collecting pdfplumber>=0.11.4 (from crewai)
#   Using cached pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: portalocker==2.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (2.10.1)
# Collecting pydantic>=2.11.9 (from crewai)
#   Using cached pydantic-2.12.0-py3-none-any.whl.metadata (83 kB)
# Requirement already satisfied: pyjwt>=2.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (2.10.1)
# Requirement already satisfied: python-dotenv>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (1.1.1)
# Collecting pyvis>=0.3.2 (from crewai)
#   Using cached pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: regex>=2024.9.11 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (2025.9.18)
# Requirement already satisfied: tokenizers>=0.20.3 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (0.22.0)
# Requirement already satisfied: tomli-w>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (2.3.0)
# Requirement already satisfied: uv>=0.4.25 in /opt/anaconda3/lib/python3.12/site-packages (from crewai) (0.9.2)
# Requirement already satisfied: aiohttp>=3.10 in /opt/anaconda3/lib/python3.12/site-packages (from litellm==1.74.9->crewai) (3.12.15)
# Requirement already satisfied: httpx>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from litellm==1.74.9->crewai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from litellm==1.74.9->crewai) (7.0.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from litellm==1.74.9->crewai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from litellm==1.74.9->crewai) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from litellm==1.74.9->crewai) (0.11.0)
# Requirement already satisfied: build>=1.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (1.26.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (1.22.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (1.37.0)
# Requirement already satisfied: pypika>=0.48.9 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (1.75.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from chromadb~=1.1.0->crewai) (14.1.0)
# Collecting diskcache>=5.6.3 (from instructor>=1.3.3->crewai)
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (0.17.0)
# Collecting jiter<0.11,>=0.6.1 (from instructor>=1.3.3->crewai)
#   Using cached jiter-0.10.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (2.33.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /opt/anaconda3/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (2.32.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (1.3.0)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/lib/python3.12/site-packages (from openpyxl>=3.1.5->crewai) (1.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.37.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-proto==1.37.0->opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-sdk>=1.30.0->crewai) (0.58b0)
# Collecting pdfminer.six==20250506 (from pdfplumber>=0.11.4->crewai)
#   Using cached pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /opt/anaconda3/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (3.4.3)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (43.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.11.9->crewai) (0.6.0)
# Collecting pydantic-core<3.0.0,>=2.18.0 (from instructor>=1.3.3->crewai)
#   Using cached pydantic_core-2.41.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.11.9->crewai) (0.4.2)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (8.27.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in /opt/anaconda3/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (3.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/anaconda3/lib/python3.12/site-packages (from tokenizers>=0.20.3->crewai) (0.35.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.74.9->crewai) (1.20.1)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai) (2.10)
# Requirement already satisfied: packaging>=19.1 in /opt/anaconda3/lib/python3.12/site-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (24.2)
# Requirement already satisfied: pyproject_hooks in /opt/anaconda3/lib/python3.12/site-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.23.0->litellm==1.74.9->crewai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.23.0->litellm==1.74.9->crewai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.74.9->crewai) (0.16.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (1.1.10)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm==1.74.9->crewai) (3.17.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.74.9->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.9->crewai) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.9->crewai) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.9->crewai) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in /opt/anaconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.10)
# Requirement already satisfied: coloredlogs in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (25.2.10)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.14.0)
# Requirement already satisfied: backoff>=1.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (2.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (2.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (4.9.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb~=1.1.0->crewai) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.5)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/anaconda3/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (10.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.3.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (2.23)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.4.8)
# Using cached crewai-0.203.0-py3-none-any.whl (473 kB)
# Using cached litellm-1.74.9-py3-none-any.whl (8.7 MB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached instructor-1.11.3-py3-none-any.whl (155 kB)
# Using cached opentelemetry_exporter_otlp_proto_http-1.37.0-py3-none-any.whl (19 kB)
# Using cached pdfplumber-0.11.7-py3-none-any.whl (60 kB)
# Using cached pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
# Using cached pydantic-2.12.0-py3-none-any.whl (459 kB)
# Using cached pydantic_core-2.41.1-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
# Using cached pyvis-0.3.2-py3-none-any.whl (756 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Using cached jiter-0.10.0-cp312-cp312-macosx_11_0_arm64.whl (320 kB)
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# Installing collected packages: pydantic-core, jiter, diskcache, blinker, pydantic, pdfminer.six, pyvis, pdfplumber, litellm, instructor, opentelemetry-exporter-otlp-proto-http, crewai
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.2
#     Uninstalling pydantic_core-2.33.2:
#       Successfully uninstalled pydantic_core-2.33.2
#   Attempting uninstall: jiter
#     WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
#     Found existing installation: jiter 0.11.0
#     Uninstalling jiter-0.11.0:
#       Successfully uninstalled jiter-0.11.0
#   Attempting uninstall: blinker
#     WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
#     Found existing installation: blinker 1.6.2
#     Uninstalling blinker-1.6.2:
#       Successfully uninstalled blinker-1.6.2
#   Attempting uninstall: pydantic
#     WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
#     Found existing installation: pydantic 2.11.7
#     Uninstalling pydantic-2.11.7:
#       Successfully uninstalled pydantic-2.11.7
#   Attempting uninstall: litellm
#     Found existing installation: litellm 1.77.7
#     Uninstalling litellm-1.77.7:
#       Successfully uninstalled litellm-1.77.7
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.7.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# gradio 5.34.2 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0 which is incompatible.
# streamlit 1.37.1 requires rich<14,>=10.14.0, but you have rich 14.1.0 which is incompatible.
# Successfully installed blinker-1.9.0 crewai-0.203.0 diskcache-5.6.3 instructor-1.11.3 jiter-0.10.0 litellm-1.74.9 opentelemetry-exporter-otlp-proto-http-1.37.0 pdfminer.six-20250506 pdfplumber-0.11.7 pydantic-2.12.0 pydantic-core-2.41.1 pyvis-0.3.2
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~orchvision (/opt/anaconda3/lib/python3.12/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from crewai import Agent, Task, Crew, Process
from langchain.tools import DuckDuckGoSearchRun

# %%
# Set gemini pro as llm
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash",
                             verbose = True,
                             temperature = 0.5,
                             google_api_key="AIzaSyD4wjxz1ZuoTatsxxXSPFM9jxmNoda4A2A")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760250057.138183  292651 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.

# %%
#google new model == gemini-1.5-flash-8b-exp-0827

# %%
#create searches
tool_search = DuckDuckGoSearchRun()

# %%
# Define Agents
email_author = Agent(
    role='Professional Email Author',
    goal='Craft concise and engaging emails',
    backstory='Experienced in writing impactful marketing emails.',
    verbose=True,
    allow_delegation=False,
    llm=llm,
    tools=[
        tool_search
      ]
)
marketing_strategist = Agent(
    role='Marketing Strategist',
    goal='Lead the team in creating effective cold emails',
    backstory='A seasoned Chief Marketing Officer with a keen eye for standout marketing content.',
    verbose=True,
    allow_delegation=True,
    llm=llm
)

content_specialist = Agent(
    role='Content Specialist',
    goal='Critique and refine email content',
    backstory='A professional copywriter with a wealth of experience in persuasive writing.',
    verbose=True,
    allow_delegation=False,
    llm=llm
)

# Define Task
email_task = Task(
    description='''1. Generate two distinct variations of a cold email promoting a video editing solution.
    2. Evaluate the written emails for their effectiveness and engagement.
    3. Scrutinize the emails for grammatical correctness and clarity.
    4. Adjust the emails to align with best practices for cold outreach. Consider the feedback
    provided to the marketing_strategist.
    5. Revise the emails based on all feedback, creating two final versions.''',
    agent=marketing_strategist,  # The Marketing Strategist is in charge and can delegate
    expected_output=""
    )


# Create a Single Crew
email_crew = Crew(
    agents=[email_author, marketing_strategist, content_specialist],
    tasks=[email_task],
    verbose=True,
    process=Process.sequential
)

# Execution Flow
print("Crew: Working on Email Task")
emails_output = email_crew.kickoff()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Define Agents
# ----> 2 email_author = Agent(
#       3     role='Professional Email Author',
#       4     goal='Craft concise and engaging emails',
#       5     backstory='Experienced in writing impactful marketing emails.',
#       6     verbose=True,
#       7     allow_delegation=False,
#       8     llm=llm,
#       9     tools=[
#      10         tool_search
#      11       ]
#      12 )
#      13 marketing_strategist = Agent(
#      14     role='Marketing Strategist',
#      15     goal='Lead the team in creating effective cold emails',
#    (...)
#      19     llm=llm
#      20 )
#      22 content_specialist = Agent(
#      23     role='Content Specialist',
#      24     goal='Critique and refine email content',
#    (...)
#      28     llm=llm
#      29 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pydantic/main.py:253, in __init__(self, **data)
#     250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
# --> 253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for Agent
# tools.0
#   Input should be a valid dictionary or instance of BaseTool [type=model_type, input_value=DuckDuckGoSearchRun(api_w...='auto', source='text')), input_type=DuckDuckGoSearchRun]
#     For further information visit https://errors.pydantic.dev/2.11/v/model_type

# %%
from crewai import Agent, Task, Crew, Process

# Define Agents
email_author = Agent(
    role='Professional Email Author',
    goal='Craft concise and engaging emails',
    backstory='Experienced in writing impactful marketing emails.',
    verbose=True,
    allow_delegation=False,
    llm=llm,  # Replace with your LLM instance
    tools=[tool_search]  # Replace with your search tool instance
)

marketing_strategist = Agent(
    role='Marketing Strategist',
    goal='Lead the team in creating effective cold emails',
    backstory='A seasoned Chief Marketing Officer with a keen eye for standout marketing content.',
    verbose=True,
    allow_delegation=True,
    llm=llm
)

content_specialist = Agent(
    role='Content Specialist',
    goal='Critique and refine email content',
    backstory='A professional copywriter with a wealth of experience in persuasive writing.',
    verbose=True,
    allow_delegation=False,
    llm=llm
)

# Define Task
email_task = Task(
    description='''
    1. Generate two distinct variations of a cold email promoting a video editing solution.
    2. Evaluate the written emails for their effectiveness and engagement.
    3. Scrutinize the emails for grammatical correctness and clarity.
    4. Adjust the emails to align with best practices for cold outreach. Consider the feedback
       provided to the marketing_strategist.
    5. Revise the emails based on all feedback, creating two final versions.
    ''',
    agent=marketing_strategist,  # Lead agent
    expected_output="Two final refined email versions optimized for cold outreach."
)

# Create a Single Crew
email_crew = Crew(
    agents=[email_author, marketing_strategist, content_specialist],
    tasks=[email_task],
    verbose=True,
    process=Process.sequential
)

# Execution Flow
if __name__ == "__main__":
    print("Crew: Working on Email Task")
    emails_output = email_crew.kickoff()
    print("\n--- Final Output ---\n")
    print(emails_output)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[10], line 4
#       1 from crewai import Agent, Task, Crew, Process
#       3 # Define Agents
# ----> 4 email_author = Agent(
#       5     role='Professional Email Author',
#       6     goal='Craft concise and engaging emails',
#       7     backstory='Experienced in writing impactful marketing emails.',
#       8     verbose=True,
#       9     allow_delegation=False,
#      10     llm=llm,  # Replace with your LLM instance
#      11     tools=[tool_search]  # Replace with your search tool instance
#      12 )
#      14 marketing_strategist = Agent(
#      15     role='Marketing Strategist',
#      16     goal='Lead the team in creating effective cold emails',
#    (...)
#      20     llm=llm
#      21 )
#      23 content_specialist = Agent(
#      24     role='Content Specialist',
#      25     goal='Critique and refine email content',
#    (...)
#      29     llm=llm
#      30 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pydantic/main.py:253, in __init__(self, **data)
#     250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
# --> 253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for Agent
# tools.0
#   Input should be a valid dictionary or instance of BaseTool [type=model_type, input_value=DuckDuckGoSearchRun(api_w...='auto', source='text')), input_type=DuckDuckGoSearchRun]
#     For further information visit https://errors.pydantic.dev/2.11/v/model_type
